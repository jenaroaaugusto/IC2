# %% [markdown]
# <a href="https://colab.research.google.com/github/jenaroaaugusto/IC2/blob/master/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf 
from __future__ import absolute_import, division, print_function, unicode_literals
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import pathlib
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl


from tensorflow.keras import datasets, layers, models,optimizers
from tensorflow.keras.layers import Activation, Dense

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# #Carragemento dos dados

# %%
# !git clone https://github.com/jenaroaaugusto/Music_Symbols.git
# Out:
# Cloning into 'Music_Symbols'...
# remote: Enumerating objects: 4151, done.
# remote: Counting objects: 100% (4151/4151), done.
# remote: Compressing objects: 100% (2705/2705), done.
# remote: Total 4151 (delta 1456), reused 4136 (delta 1444), pack-reused 0
# Receiving objects: 100% (4151/4151), 1.47 MiB | 14.90 MiB/s, done.
# Resolving deltas: 100% (1456/1456), done.

# %%
trainDir = os.path.join('/content/Music_Symbols/conjunto', 'train')
# validationDir=os.path.join('/content/Dataset_musica_semvalidacao', 'Teste')
testDir= os.path.join('/content/Music_Symbols/conjunto','val')

# %%
train_dir = pathlib.Path(""+trainDir)
print(train_dir)
total_train = len(list(train_dir.glob('*/*.bmp')))
print(total_train)
CLASS_NAMES=np.array(os.listdir(train_dir))
print(CLASS_NAMES)
# Out:
# /content/Music_Symbols/conjunto/train
# 3271
# ['CLEF_Bass' 'ACCIDENTAL_Flat' 'ACCIDENTAL_Sharp' 'CLEF_Alto'
#  'ACCIDENTAL_DoubSharp' 'CLEF_Trebble' 'ACCIDENTAL_Natural']

# %%
test_dir = pathlib.Path(""+testDir)
print(test_dir)
total_test = len(list(test_dir.glob('*/*.bmp')))
print(total_test)
CLASS_NAMEST=np.array(os.listdir(test_dir))
print(CLASS_NAMEST)
# Out:
# /content/Music_Symbols/conjunto/val
# 822
# ['CLEF_Bass' 'ACCIDENTAL_Flat' 'ACCIDENTAL_Sharp' 'CLEF_Alto'
#  'ACCIDENTAL_DoubSharp' 'CLEF_Trebble' 'ACCIDENTAL_Natural']

# %%
diretorio=os.listdir(test_dir)
caminhos=list(test_dir.glob('*/*.bmp'))

# %% [markdown]
# #Definição de execução

# %%
batch_size = 32
epochs = 20
IMG_HEIGHT = 28
IMG_WIDTH = 28

# %% [markdown]
# #Pre-Procesamento
# Geração do Generator

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    width_shift_range=.15,
                                    height_shift_range=.15,
                                    rotation_range=45,
                                    horizontal_flip=True,
                                    vertical_flip=True,
                                    validation_split = .2)
val_datagen = ImageDataGenerator(rescale=1./255,
                                  validation_split = .2)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(train_dir,
                                        target_size=(IMG_HEIGHT, IMG_WIDTH),
                                        batch_size=32,
                                        color_mode="grayscale",
                                        class_mode='categorical',
                                        shuffle = True,
                                        subset='training')

validation_set = val_datagen.flow_from_directory(train_dir,
                                        target_size=(IMG_HEIGHT, IMG_WIDTH),
                                        batch_size=32,
                                        color_mode="grayscale",
                                        class_mode='categorical',
                                        shuffle = False,
                                        subset='validation')

test_set = test_datagen.flow_from_directory(test_dir,
                                        target_size=(IMG_HEIGHT, IMG_WIDTH),
                                        batch_size=32,
                                        color_mode="grayscale",
                                        class_mode='categorical',
                                        shuffle = False,)
# Out:
# Found 2621 images belonging to 7 classes.
# Found 651 images belonging to 7 classes.
# Found 822 images belonging to 7 classes.

# %% [markdown]
# #Rede Neural Convolucional

# %% [markdown]
# #CNN

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (2, 2),padding="same", 
                            activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(64, (3, 3),padding="same", activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3),padding="same", activation='relu'))
model.add(layers.MaxPooling2D(2,2))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# =================================================================
# Total params: 92,512
# Trainable params: 92,512
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Camada Densa

# %%
model.add(layers.Flatten())
model.add(layers.Dropout(0.1))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(Dense(7))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               147584
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 77
# _________________________________________________________________
# activation (Activation)      (None, 7)                 0
# =================================================================
# Total params: 249,079
# Trainable params: 249,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Definição de Metricas

# %%
METRICS = [
      tf.keras.metrics.TruePositives(name='tp'),
      tf.keras.metrics.FalsePositives(name='fp'),
      tf.keras.metrics.TrueNegatives(name='tn'),
      tf.keras.metrics.FalseNegatives(name='fn'), 
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
]

# %% [markdown]
# #Definição de complicalção
#
# *   Função de Otimização
# *   Função de perda
# *   Metricas de avaliação

# %%
model.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=METRICS)

# %% [markdown]
# #Visualização do modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               147584
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 77
# _________________________________________________________________
# activation (Activation)      (None, 7)                 0
# =================================================================
# Total params: 249,079
# Trainable params: 249,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Treinamento

# %%
history = model.fit(training_set,
                    steps_per_epoch=training_set.samples// batch_size,
                    epochs=epochs,
                    validation_data=validation_set,
                    validation_steps = validation_set.samples// batch_size)
# Out:
# Epoch 1/20
# 81/81 [==============================] - 7s 82ms/step - loss: 1.8257 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 15552.0000 - fn: 2592.0000 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6444 - val_loss: 1.6325 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 3840.0000 - val_fn: 640.0000 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7570
# Epoch 2/20
# 81/81 [==============================] - 6s 72ms/step - loss: 1.5589 - tp: 82.0000 - fp: 51.0000 - tn: 15483.0000 - fn: 2507.0000 - accuracy: 0.8589 - precision: 0.6165 - recall: 0.0317 - auc: 0.7829 - val_loss: 2.1878 - val_tp: 43.0000 - val_fp: 1.0000 - val_tn: 3839.0000 - val_fn: 597.0000 - val_accuracy: 0.8665 - val_precision: 0.9773 - val_recall: 0.0672 - val_auc: 0.6948
# Epoch 3/20
# 81/81 [==============================] - 6s 72ms/step - loss: 1.3647 - tp: 290.0000 - fp: 180.0000 - tn: 15354.0000 - fn: 2299.0000 - accuracy: 0.8632 - precision: 0.6170 - recall: 0.1120 - auc: 0.8401 - val_loss: 2.0600 - val_tp: 151.0000 - val_fp: 126.0000 - val_tn: 3714.0000 - val_fn: 489.0000 - val_accuracy: 0.8627 - val_precision: 0.5451 - val_recall: 0.2359 - val_auc: 0.7315
# Epoch 4/20
# 81/81 [==============================] - 6s 73ms/step - loss: 1.2091 - tp: 582.0000 - fp: 265.0000 - tn: 15269.0000 - fn: 2007.0000 - accuracy: 0.8746 - precision: 0.6871 - recall: 0.2248 - auc: 0.8765 - val_loss: 1.7576 - val_tp: 226.0000 - val_fp: 238.0000 - val_tn: 3602.0000 - val_fn: 414.0000 - val_accuracy: 0.8545 - val_precision: 0.4871 - val_recall: 0.3531 - val_auc: 0.7936
# Epoch 5/20
# 81/81 [==============================] - 6s 74ms/step - loss: 1.0557 - tp: 1044.0000 - fp: 528.0000 - tn: 15006.0000 - fn: 1545.0000 - accuracy: 0.8856 - precision: 0.6641 - recall: 0.4032 - auc: 0.9057 - val_loss: 1.6563 - val_tp: 263.0000 - val_fp: 235.0000 - val_tn: 3605.0000 - val_fn: 377.0000 - val_accuracy: 0.8634 - val_precision: 0.5281 - val_recall: 0.4109 - val_auc: 0.8190
# Epoch 6/20
# 81/81 [==============================] - 6s 72ms/step - loss: 0.9436 - tp: 1243.0000 - fp: 612.0000 - tn: 14922.0000 - fn: 1346.0000 - accuracy: 0.8920 - precision: 0.6701 - recall: 0.4801 - auc: 0.9241 - val_loss: 1.1740 - val_tp: 282.0000 - val_fp: 162.0000 - val_tn: 3678.0000 - val_fn: 358.0000 - val_accuracy: 0.8839 - val_precision: 0.6351 - val_recall: 0.4406 - val_auc: 0.8890
# Epoch 7/20
# 81/81 [==============================] - 6s 71ms/step - loss: 0.8101 - tp: 1526.0000 - fp: 532.0000 - tn: 15002.0000 - fn: 1063.0000 - accuracy: 0.9120 - precision: 0.7415 - recall: 0.5894 - auc: 0.9439 - val_loss: 1.8751 - val_tp: 268.0000 - val_fp: 319.0000 - val_tn: 3521.0000 - val_fn: 372.0000 - val_accuracy: 0.8458 - val_precision: 0.4566 - val_recall: 0.4187 - val_auc: 0.8281
# Epoch 8/20
# 81/81 [==============================] - 6s 72ms/step - loss: 0.7316 - tp: 1677.0000 - fp: 531.0000 - tn: 15003.0000 - fn: 912.0000 - accuracy: 0.9204 - precision: 0.7595 - recall: 0.6477 - auc: 0.9541 - val_loss: 1.5039 - val_tp: 385.0000 - val_fp: 206.0000 - val_tn: 3634.0000 - val_fn: 255.0000 - val_accuracy: 0.8971 - val_precision: 0.6514 - val_recall: 0.6016 - val_auc: 0.8717
# Epoch 9/20
# 81/81 [==============================] - 6s 72ms/step - loss: 0.6292 - tp: 1844.0000 - fp: 469.0000 - tn: 15065.0000 - fn: 745.0000 - accuracy: 0.9330 - precision: 0.7972 - recall: 0.7122 - auc: 0.9657 - val_loss: 1.0912 - val_tp: 407.0000 - val_fp: 170.0000 - val_tn: 3670.0000 - val_fn: 233.0000 - val_accuracy: 0.9100 - val_precision: 0.7054 - val_recall: 0.6359 - val_auc: 0.9152
# Epoch 10/20
# 81/81 [==============================] - 6s 71ms/step - loss: 0.5684 - tp: 1915.0000 - fp: 450.0000 - tn: 15084.0000 - fn: 674.0000 - accuracy: 0.9380 - precision: 0.8097 - recall: 0.7397 - auc: 0.9714 - val_loss: 0.9429 - val_tp: 458.0000 - val_fp: 131.0000 - val_tn: 3709.0000 - val_fn: 182.0000 - val_accuracy: 0.9301 - val_precision: 0.7776 - val_recall: 0.7156 - val_auc: 0.9375
# Epoch 11/20
# 81/81 [==============================] - 6s 71ms/step - loss: 0.5072 - tp: 1990.0000 - fp: 409.0000 - tn: 15125.0000 - fn: 599.0000 - accuracy: 0.9444 - precision: 0.8295 - recall: 0.7686 - auc: 0.9770 - val_loss: 1.2789 - val_tp: 426.0000 - val_fp: 168.0000 - val_tn: 3672.0000 - val_fn: 214.0000 - val_accuracy: 0.9147 - val_precision: 0.7172 - val_recall: 0.6656 - val_auc: 0.9128
# Epoch 12/20
# 81/81 [==============================] - 6s 72ms/step - loss: 0.5200 - tp: 2015.0000 - fp: 418.0000 - tn: 15116.0000 - fn: 574.0000 - accuracy: 0.9453 - precision: 0.8282 - recall: 0.7783 - auc: 0.9758 - val_loss: 0.8918 - val_tp: 465.0000 - val_fp: 125.0000 - val_tn: 3715.0000 - val_fn: 175.0000 - val_accuracy: 0.9330 - val_precision: 0.7881 - val_recall: 0.7266 - val_auc: 0.9440
# Epoch 13/20
# 81/81 [==============================] - 6s 71ms/step - loss: 0.4276 - tp: 2120.0000 - fp: 339.0000 - tn: 15195.0000 - fn: 469.0000 - accuracy: 0.9554 - precision: 0.8621 - recall: 0.8188 - auc: 0.9833 - val_loss: 1.3535 - val_tp: 411.0000 - val_fp: 190.0000 - val_tn: 3650.0000 - val_fn: 229.0000 - val_accuracy: 0.9065 - val_precision: 0.6839 - val_recall: 0.6422 - val_auc: 0.9007
# Epoch 14/20
# 81/81 [==============================] - 6s 73ms/step - loss: 0.4338 - tp: 2111.0000 - fp: 351.0000 - tn: 15183.0000 - fn: 478.0000 - accuracy: 0.9543 - precision: 0.8574 - recall: 0.8154 - auc: 0.9830 - val_loss: 0.6943 - val_tp: 491.0000 - val_fp: 116.0000 - val_tn: 3724.0000 - val_fn: 149.0000 - val_accuracy: 0.9408 - val_precision: 0.8089 - val_recall: 0.7672 - val_auc: 0.9590
# Epoch 15/20
# 81/81 [==============================] - 6s 72ms/step - loss: 0.3945 - tp: 2160.0000 - fp: 325.0000 - tn: 15209.0000 - fn: 429.0000 - accuracy: 0.9584 - precision: 0.8692 - recall: 0.8343 - auc: 0.9854 - val_loss: 0.7149 - val_tp: 478.0000 - val_fp: 138.0000 - val_tn: 3702.0000 - val_fn: 162.0000 - val_accuracy: 0.9330 - val_precision: 0.7760 - val_recall: 0.7469 - val_auc: 0.9657
# Epoch 16/20
# 81/81 [==============================] - 6s 71ms/step - loss: 0.3933 - tp: 2148.0000 - fp: 343.0000 - tn: 15191.0000 - fn: 441.0000 - accuracy: 0.9567 - precision: 0.8623 - recall: 0.8297 - auc: 0.9861 - val_loss: 0.6139 - val_tp: 512.0000 - val_fp: 100.0000 - val_tn: 3740.0000 - val_fn: 128.0000 - val_accuracy: 0.9491 - val_precision: 0.8366 - val_recall: 0.8000 - val_auc: 0.9710
# Epoch 17/20
# 81/81 [==============================] - 6s 72ms/step - loss: 0.3761 - tp: 2166.0000 - fp: 327.0000 - tn: 15207.0000 - fn: 423.0000 - accuracy: 0.9586 - precision: 0.8688 - recall: 0.8366 - auc: 0.9869 - val_loss: 0.7174 - val_tp: 480.0000 - val_fp: 137.0000 - val_tn: 3703.0000 - val_fn: 160.0000 - val_accuracy: 0.9337 - val_precision: 0.7780 - val_recall: 0.7500 - val_auc: 0.9620
# Epoch 18/20
# 81/81 [==============================] - 6s 71ms/step - loss: 0.3523 - tp: 2184.0000 - fp: 308.0000 - tn: 15226.0000 - fn: 405.0000 - accuracy: 0.9607 - precision: 0.8764 - recall: 0.8436 - auc: 0.9886 - val_loss: 0.5296 - val_tp: 518.0000 - val_fp: 92.0000 - val_tn: 3748.0000 - val_fn: 122.0000 - val_accuracy: 0.9522 - val_precision: 0.8492 - val_recall: 0.8094 - val_auc: 0.9727
# Epoch 19/20
# 81/81 [==============================] - 6s 72ms/step - loss: 0.3120 - tp: 2250.0000 - fp: 272.0000 - tn: 15262.0000 - fn: 339.0000 - accuracy: 0.9663 - precision: 0.8921 - recall: 0.8691 - auc: 0.9905 - val_loss: 0.7805 - val_tp: 492.0000 - val_fp: 122.0000 - val_tn: 3718.0000 - val_fn: 148.0000 - val_accuracy: 0.9397 - val_precision: 0.8013 - val_recall: 0.7688 - val_auc: 0.9574
# Epoch 20/20
# 81/81 [==============================] - 6s 71ms/step - loss: 0.3283 - tp: 2234.0000 - fp: 281.0000 - tn: 15253.0000 - fn: 355.0000 - accuracy: 0.9649 - precision: 0.8883 - recall: 0.8629 - auc: 0.9897 - val_loss: 1.0911 - val_tp: 451.0000 - val_fp: 171.0000 - val_tn: 3669.0000 - val_fn: 189.0000 - val_accuracy: 0.9196 - val_precision: 0.7251 - val_recall: 0.7047 - val_auc: 0.9367

# %% [markdown]
# #Visualizar Resultados

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def plot_loss(history, label, n):
  # Use a log scale to show the wide range of values.
  plt.semilogy(history.epoch,  history.history['loss'],
               color=colors[n], label='Train '+label)
  plt.semilogy(history.epoch,  history.history['val_loss'],
          color=colors[n], label='Val '+label,
          linestyle="--")
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  
  plt.legend()

# %%
plot_loss(history, "Conjunto", 0)

# %%
def plot_metrics(history):
  metrics =  ['loss', 'auc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

# %%
plot_metrics(history)

# %% [markdown]
# #Predict

# %%
nb=len(training_set.filenames)
ny=len(test_set.filenames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d38e50a585c> in <module>()
# ----> 1 nb=len(training_set.filenames)
#       2 ny=len(test_set.filenames)
#
# NameError: name 'training_set' is not defined

# %%
 axy=test_set.class_indices
 names=list(axy.keys())
 nomedasclasses = np.array(names)

# %%
train_predictions_baseline = model.predict(training_set,steps=np.ceil(nb/batch_size))

test_predictions_baseline = model.predict(test_set,steps=np.ceil(ny/batch_size))

# %%
true_labelsTrain=training_set.classes

true_labels =test_set.classes

# %%
y_true = true_labels
y_pred = np.array([np.argmax(x) for x in test_predictions_baseline])

x_true = true_labelsTrain
x_pred = np.array([np.argmax(x) for x in train_predictions_baseline])

# %%
tf.math.confusion_matrix(y_true,y_pred)
# Out:
# <tf.Tensor: shape=(7, 7), dtype=int32, numpy=
# array([[ 92,   0,   1,   6,   1,   0,   0],
#        [  0,  41,  62,   1,   0,   0,   0],
#        [  0,   0,  82,   2,   0,   0,  11],
#        [  0,   0,   0,  79,   1,   0,  17],
#        [  0,   0,   0,   0, 124,   0,  28],
#        [  0,   0,   2,   0,   4, 100,   4],
#        [  0,   0,   0,   0,   2,   0, 162]], dtype=int32)>

# %%
con_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred).numpy()
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)

con_mat_df = pd.DataFrame(con_mat_norm,
                     index = nomedasclasses, 
                     columns = nomedasclasses)

figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues,cbar=False)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# #Evaluate

# %%
baseline_results  = model.evaluate(test_set,batch_size=32,steps=np.ceil(nb/batch_size))
# Out:
# 82/82 [==============================] - 2s 22ms/step - loss: 0.5207 - tp: 2127.0000 - fp: 438.0000 - tn: 15126.0000 - fn: 467.0000 - accuracy: 0.9502 - precision: 0.8292 - recall: 0.8200 - auc: 0.9788

# %%
for name, value in zip(model.metrics_names, baseline_results):
  print(name, ': ', value)
print()
# Out:
# loss :  0.5207143425941467
# tp :  2127.0
# fp :  438.0
# tn :  15126.0
# fn :  467.0
# accuracy :  0.9501596689224243
# precision :  0.8292397856712341
# recall :  0.8199691772460938
# auc :  0.9788224101066589

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96       100
#            1       1.00      0.39      0.57       104
#            2       0.56      0.86      0.68        95
#            3       0.90      0.81      0.85        97
#            4       0.94      0.82      0.87       152
#            5       1.00      0.91      0.95       110
#            6       0.73      0.99      0.84       164
#
#     accuracy                           0.83       822
#    macro avg       0.87      0.81      0.82       822
# weighted avg       0.87      0.83      0.82       822

# %%
confusion_matrix(y_true,y_pred)
# Out:
# array([[ 92,   0,   1,   6,   1,   0,   0],
#        [  0,  41,  62,   1,   0,   0,   0],
#        [  0,   0,  82,   2,   0,   0,  11],
#        [  0,   0,   0,  79,   1,   0,  17],
#        [  0,   0,   0,   0, 124,   0,  28],
#        [  0,   0,   2,   0,   4, 100,   4],
#        [  0,   0,   0,   0,   2,   0, 162]])

# %%
con_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred).numpy()
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)

con_mat_df = pd.DataFrame(con_mat_norm,
                     index = nomedasclasses, 
                     columns = nomedasclasses)

figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues,cbar=False)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
con_mat = tf.math.confusion_matrix(labels=y_true, predictions=y_pred).numpy()
# con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)

con_mat_df = pd.DataFrame(con_mat,
                     index = nomedasclasses, 
                     columns = nomedasclasses)

figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues,cbar=False)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
